# %% [markdown]
# Escribir un programa que calcule las ra ́ıces de
#
# ax2 + bx + c = 0 (1)
#
# Esto lo puede hacer con la ecuaci ́on general de segundo orden
#
# Si el discriminante (b**2 − 4ac) es negativo, entonces debe de imprimir
#
# Error, el discriminante tiene que se positivo
# y debe de volver a leer los valores de los coeficientes a, b y c, esto se debe de ciclar hasta que
# el discriminante sea positivo.

# %%
from math import sqrt

def ecuacion(a,b,c):
    determinante = (b * b) - (4 * a * c)
    while (determinante < 0):
          print ("Error, el discriminante tiene que ser positivo ")
          a = int (input("introduce el valor de a: "))
          b = int (input("introduce el valor de b: "))
          c = int (input("introduce el valor de b: "))
          determinante = (b * b) - (4 * a * c)

    if (determinante > 0):
      x_1 = (-b + sqrt ((b*b) - (4*a*c))) / 2*a
      x_2 = (-b - sqrt ((b*b) - (4*a*c))) / 2*a
      return (x_1, x_2)
    elif (determinante == 0):
      x_1 = -b / (2*a)
      return (x_1)

a = int (input("introduce el valor de a: "))
b = int (input("introduce el valor de b: "))
c = int (input("introduce el valor de b: "))
print("la respuesta es: ",ecuacion(a,b,c))
# Out:
# introduce el valor de a: 1
# introduce el valor de b: 2
# introduce el valor de b: 1
# la respuesta es:  -1.0

# %% [markdown]
# Sea la funci ́on
#
# f(x) = e^−x
#
# Realizar un funci ́on que acepte como argumento el valor de x, que calcule el valor de f(x) y que lo regrese a la funci ́on principal.
#
# En el programa principal, debe de hacer un bucle que ayude a evaluar la funci ́on con valores desde -4 hasta 10 y que pare el bucle cuando el valor e f(x) sea menor que 0.0025, Guardar en una lista el valor de las iteraciones conforme van pasando.
#
# Pistas: Debes de utilizar el bucle while con un contador que comienza en -4 y debe de ir sumando en uno.
#
# La lista vac ́ıa se declara con miLista=[] y cada que quieras agregar alg ́un elemento te conviene utilizar .append(valor). puedes declarar e = 2.7182818284 como una variable y despu ́es hacer la matem ́atica correspondiente.

# %%
def ecuacion(x):
    e = 2.7182818284
    return ( e ** (-x))
    
lista=[]
x = -4
while (ecuacion (x) >= .0025):
      lista.append(ecuacion (x))
      x = x +1
print (lista)
# Out:
# [54.59815002840041, 20.0855369218788, 7.389056098609647, 2.7182818284, 1.0, 0.3678794411794332, 0.13533528324249208, 0.0497870683711083, 0.01831563889032556, 0.006737946999817261]
